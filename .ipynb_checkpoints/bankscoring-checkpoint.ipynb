# %%
pip install -U --user scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\user\anaconda3\lib\site-packages (1.0.1)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pandas import Series


import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import f_classif, mutual_info_classif
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix
from sklearn.metrics import auc, roc_auc_score, roc_curve,precision_recall_curve,average_precision_score
from sklearn.metrics import log_loss,accuracy_score,precision_score, recall_score,f1_score
from sklearn.experimental import enable_halving_search_cv  # noqa
#from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import HalvingGridSearchCV

# %%
# , encoding = 'ISO-8859-1',low_memory = False
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73799 entries, 0 to 73798
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         73799 non-null  int64
#  1   app_date          73799 non-null  object
#  2   education         73492 non-null  object
#  3   sex               73799 non-null  object
#  4   age               73799 non-null  int64
#  5   car               73799 non-null  object
#  6   car_type          73799 non-null  object
#  7   decline_app_cnt   73799 non-null  int64
#  8   good_work         73799 non-null  int64
#  9   score_bki         73799 non-null  float64
#  10  bki_request_cnt   73799 non-null  int64
#  11  region_rating     73799 non-null  int64
#  12  home_address      73799 non-null  int64
#  13  work_address      73799 non-null  int64
#  14  income            73799 non-null  int64
#  15  sna               73799 non-null  int64
# ...

# %%
sample_submission = pd.read_csv("sample_submission.csv")

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24354 entries, 0 to 24353
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  24354 non-null  int64
#  1   default    24354 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 380.7 KB

# %%
df_test.sample(5)
# Out:
#        client_id   app_date education sex  age car car_type  decline_app_cnt  \
# 27035      52695  01MAR2014       GRD   F   43   Y        Y                0
# 2327       62379  11MAR2014       UGR   M   29   Y        N                0
# 13561      21599  28JAN2014       SCH   F   46   N        N                0
# 24310      65493  14MAR2014       UGR   M   47   Y        N                0
# 9736       29138  05FEB2014       UGR   F   28   N        N                0
#
#        good_work  score_bki  bki_request_cnt  region_rating  home_address  \
# 27035          1  -1.420699                0             50             1
# 2327           0  -1.423982                1             80             2
# 13561          0  -1.117199                2             70             1
# 24310          1  -1.619837                1             80             2
# 9736           0  -1.076489                1             50             1
#
# ...

# %%
df_test.query('client_id==66799')
# Out:
# Empty DataFrame
# Columns: [client_id, app_date, education, sex, age, car, car_type, decline_app_cnt, good_work, score_bki, bki_request_cnt, region_rating, home_address, work_address, income, sna, first_time, foreign_passport]
# Index: []

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36349 entries, 0 to 36348
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         36349 non-null  int64
#  1   app_date          36349 non-null  object
#  2   education         36178 non-null  object
#  3   sex               36349 non-null  object
#  4   age               36349 non-null  int64
#  5   car               36349 non-null  object
#  6   car_type          36349 non-null  object
#  7   decline_app_cnt   36349 non-null  int64
#  8   good_work         36349 non-null  int64
#  9   score_bki         36349 non-null  float64
#  10  bki_request_cnt   36349 non-null  int64
#  11  region_rating     36349 non-null  int64
#  12  home_address      36349 non-null  int64
#  13  work_address      36349 non-null  int64
#  14  income            36349 non-null  int64
#  15  sna               36349 non-null  int64
# ...

# %%
sample_submission.head(2)
# Out:
#    client_id   default
# 0      66799  0.441004
# 1      25379  0.138092

# %%
df_train['sample'] = 1 # помечаем  трейн
df_test['default'] = 0 # в тесте колонки дефолт
df_test['sample'] = 0 # помечаем  тест

vis_data = df_test.append(df_train, sort=False) # объединяем train и test

# %%
vis_data.head(2)
# Out:
#    client_id   app_date education sex  age car car_type  decline_app_cnt  \
# 0      74835  22MAR2014       GRD   M   29   Y        Y                0
# 1      17527  24JAN2014       SCH   F   39   N        N                5
#
#    good_work  score_bki  bki_request_cnt  region_rating  home_address  \
# 0          0  -2.271884                3             50             1
# 1          0  -1.504999                2             50             1
#
#    work_address  income  sna  first_time foreign_passport  default  sample
# 0             2   50000    1           4                N        0       0
# 1             2    5000    4           3                N        0       0

# %%
#изучение полных данных df_train
# создать столбец с датой
vis_data['date_'] = pd.to_datetime(vis_data.app_date, format='%d%b%Y')

# %%
# создать столбец с днем недели
vis_data['wd'] = vis_data['date_'].dt.weekday

# %%
# попытка увидеть зависимость дефолтов от дня недели
sns.displot(data=vis_data[vis_data['sample']==1], x="wd", y='default', kind='kde')

# %%
grpwd = vis_data.query('sample == 1')[['wd', 'default']].value_counts()
grpwd = grpwd.reset_index()
grpwd.columns = ['wd', 'default', 'cnt']
grp = grpwd.groupby('wd')['cnt'].sum()
grpwd['ratio'] = grpwd.apply(lambda x: x.cnt/grp[x.wd], axis=1)
grpwd
# процент дефолтов заметно не зависит от дня недели
# Out:
#     wd  default    cnt     ratio
# 0    1        0  10625  0.872618
# 1    0        0  10496  0.872921
# 2    2        0  10281  0.875724
# 3    3        0  10082  0.868015
# 4    4        0   9912  0.880050
# 5    5        0   7153  0.869032
# 6    6        0   5878  0.870815
# 7    1        1   1551  0.127382
# 8    3        1   1533  0.131985
# 9    0        1   1528  0.127079
# 10   2        1   1459  0.124276
# 11   4        1   1351  0.119950
# 12   5        1   1078  0.130968
# 13   6        1    872  0.129185

# %%
# имеющийся диапазон данных с января по май 2014 года не показывает какой-либо зависимости дефолтов от даты
sns.displot(data=vis_data.query('sample == 1'), x="date_", kind="kde", hue="default")

# %%
# на основании первичного осмотра - удалить ненужные столбцы
vis_data.drop(columns=['app_date', 'date_', 'wd'], inplace=True)
vis_data.head()
# Out:
#    client_id education sex  age car car_type  decline_app_cnt  good_work  \
# 0      74835       GRD   M   29   Y        Y                0          0
# 1      17527       SCH   F   39   N        N                5          0
# 2      75683       UGR   M   50   Y        Y                0          0
# 3      26883       SCH   M   56   N        N                0          0
# 4      28862       GRD   F   38   N        N                0          0
#
#    score_bki  bki_request_cnt  region_rating  home_address  work_address  \
# 0  -2.271884                3             50             1             2
# 1  -1.504999                2             50             1             2
# 2  -1.691339                1             50             1             2
# 3  -2.374182                1             40             1             2
# 4  -2.487502                0             80             2             3
#
#    income  sna  first_time foreign_passport  default  sample
# ...

# %%
# в столбце education пропущены данные
vis_data.isna().sum()
# Out:
# client_id             0
# education           478
# sex                   0
# age                   0
# car                   0
# car_type              0
# decline_app_cnt       0
# good_work             0
# score_bki             0
# bki_request_cnt       0
# region_rating         0
# home_address          0
# work_address          0
# income                0
# sna                   0
# first_time            0
# foreign_passport      0
# default               0
# sample                0
# dtype: int64

# %%
# заменить пропущенный тип образования на "другой" и проанализировать
vis_data['education'].fillna('other', axis=0, inplace=True)
vis_data['education'].unique()
# Out:
# array(['GRD', 'SCH', 'UGR', 'PGR', 'other', 'ACD'], dtype=object)

# %%
vis_data['edu'] = vis_data.apply(lambda x: x.education == 'other', axis=1)
vis_data.sample(5)
# Out:
#        client_id education sex  age car car_type  decline_app_cnt  good_work  \
# 6059       50674       SCH   F   43   N        N                0          0
# 45445      58029       GRD   M   43   Y        Y                0          0
# 56529      98626       SCH   M   58   Y        N                0          0
# 22450      60249       GRD   F   41   Y        Y                0          0
# 10490       8064       GRD   F   25   N        N                0          0
#
#        score_bki  bki_request_cnt  region_rating  home_address  work_address  \
# 6059   -2.196839                0             40             1             1
# 45445  -2.045975                0             50             1             1
# 56529  -2.897486                0             60             2             3
# 22450  -2.069176                1             60             1             2
# 10490  -0.723769                1             60             2             3
#
# ...

# %%
sns.displot(data=vis_data.query('sample == 1')[vis_data.query('sample == 1').income<400000], x="income", hue="edu", col="default", kind="kde")

# %%
#рассмотреть соотношение дефолтов для клиентов с заполненной строкой образования и с пропущенными данными по образованию
edudef = vis_data.query('sample == 1')[['edu', 'default']].value_counts()
display(edudef, "notnaedu", edudef[0][1]/edudef[0]
        [0], "naedu", edudef[1][1]/edudef[1][0],)
#никакой зависимости не просматривается
# Out:
# edu    default
# False  0          64155
#        1           9337
# True   0            272
#        1             35
# dtype: int64
# 'notnaedu'
# 0.14553814979346893
# 'naedu'
# 0.12867647058823528

# %%
edudef = vis_data.query('sample == 1')[['education', 'default']].value_counts()
display(edudef)
# вывести отношение дефолтных клиентов к недефолтным в зависимости от образования
for i in edudef.index:
    if i[1] == 0:
        print(i[0], "default=1/default=0",
              edudef.loc[(i[0], 1)]/edudef.loc[(i[0], 0)])
# Out:
# education  default
# SCH        0          33008
# GRD        0          21260
# UGR        0           8525
# SCH        1           5852
# GRD        1           2105
# UGR        1           1291
# PGR        0           1176
# other      0            272
# ACD        0            186
# PGR        1             81
# other      1             35
# ACD        1              8
# dtype: int64
# SCH default=1/default=0 0.17729035385361125
# GRD default=1/default=0 0.09901222953904046
# UGR default=1/default=0 0.15143695014662756
# PGR default=1/default=0 0.06887755102040816
# other default=1/default=0 0.12867647058823528
# ACD default=1/default=0 0.043010752688172046

# %%
#по соотношению дефолт1/дефолт0=0.12 для пропущенного типа образования
#не заметна выраженная связь с целевой переменной или принадлежность его к какому-нибудь из известных типов SCH...ACD

# %%
sns.displot(
    data=vis_data.query('sample == 1'), y="score_bki", hue="education", col="default",
    kind="ecdf", height=4, aspect=0.7,
)

# %%
# по результатам анализа не заметно выраженное влияние на целевую переменную,
# для клиентов с пропусками в графе education
# можно оставить пропущеный тип, как other и не причислять к одному или нескольким из известных типоу
vis_data['education'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
#удалить тестовый столбец
vis_data.drop(columns=['edu'], inplace=True)
vis_data.head(2)
# Out:
#    client_id education sex  age car car_type  decline_app_cnt  good_work  \
# 0      74835       GRD   M   29   Y        Y                0          0
# 1      17527       SCH   F   39   N        N                5          0
#
#    score_bki  bki_request_cnt  region_rating  home_address  work_address  \
# 0  -2.271884                3             50             1             2
# 1  -1.504999                2             50             1             2
#
#    income  sna  first_time foreign_passport  default  sample
# 0   50000    1           4                N        0       0
# 1    5000    4           3                N        0       0

# %%
bin_cols = []
cat_cols = []
num_cols = []
# разбивка столбцов датасета на бинарные, категориальные и числовые признаки по спискам
def splitcolumnsbyt(vis_data,postperform=None,verb=None):
    global bin_cols
    global cat_cols
    global num_cols
    bin_cols = []
    cat_cols = []
    num_cols = []
    if not verb is None:   print("разбивка столбцов на бинарные, категориальные и числовые признаки")
    for i in vis_data.columns:
        tmp = vis_data[i].unique()
        if len(tmp) == 2:
            if (i != 'default') and (i != 'sample'):
                bin_cols.append(i)
        elif len(tmp) < 10:
            cat_cols.append(i)
        else:
            if i != 'client_id':
                num_cols.append(i)
                
    if postperform is None:
        pass
    else: postperform()

    if not verb is None:
        display("бинарные:", bin_cols, "категориальные:",
            cat_cols, "числовые:", num_cols)
        print("отображение многообразия вариаций нечисловых столбцов")
        for i in (bin_cols+cat_cols):
            print(i, ":", vis_data[i].unique())


splitcolumnsbyt(vis_data,verb=True)
# Out:
# разбивка столбцов на бинарные, категориальные и числовые признаки
# 'бинарные:'
# ['sex', 'car', 'car_type', 'good_work', 'foreign_passport']
# 'категориальные:'
# ['education',
#  'region_rating',
#  'home_address',
#  'work_address',
#  'sna',
#  'first_time']
# 'числовые:'
# ['age', 'decline_app_cnt', 'score_bki', 'bki_request_cnt', 'income']
# отображение многообразия вариаций нечисловых столбцов
# sex : ['M' 'F']
# car : ['Y' 'N']
# car_type : ['Y' 'N']
# good_work : [0 1]
# foreign_passport : ['N' 'Y']
# education : ['GRD' 'SCH' 'UGR' 'PGR' 'other' 'ACD']
# region_rating : [50 40 80 60 70 20 30]
# home_address : [1 2 3]
# work_address : [2 3 1]
# sna : [1 4 2 3]
# first_time : [4 3 1 2]

# %%
sns.countplot(x='default',data=vis_data.query('sample == 1'))
#соотношение классов примерно 1:6 -, хоть и не 1:10 -но не очень сбалансированная выборка по целевой переменной
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
vis_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110148 entries, 0 to 73798
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   client_id         110148 non-null  int64
#  1   education         110148 non-null  object
#  2   sex               110148 non-null  object
#  3   age               110148 non-null  int64
#  4   car               110148 non-null  object
#  5   car_type          110148 non-null  object
#  6   decline_app_cnt   110148 non-null  int64
#  7   good_work         110148 non-null  int64
#  8   score_bki         110148 non-null  float64
#  9   bki_request_cnt   110148 non-null  int64
#  10  region_rating     110148 non-null  int64
#  11  home_address      110148 non-null  int64
#  12  work_address      110148 non-null  int64
#  13  income            110148 non-null  int64
#  14  sna               110148 non-null  int64
#  15  first_time        110148 non-null  int64
# ...

# %%
# рассмотреть распределение числовых признаков
def numplothist(df,diagtype="hist"):
    for i in range(0, len(num_cols), 2):
        fig, ax = plt.subplots(1, 2, squeeze=False, figsize=(25, 10))
        for axi in range(2):
            for labelx, labely in zip(ax[0, axi].xaxis.get_ticklabels(), ax[0, axi].yaxis.get_ticklabels()):
                labelx.set_fontsize(20)
                labely.set_fontsize(20)
        comb = [num_cols[i]]
        ax[0, 0].set_title(comb[0], fontsize='xx-large')
        if i < len(num_cols)-1:
            comb.append(num_cols[i+1])
            ax[0, 1].set_title(comb[1], fontsize='xx-large')
            if diagtype == "boxplot":
                ax[0, 0].set_xlabel('default',fontsize='xx-large')
                ax[0, 1].set_xlabel('default',fontsize='xx-large')
                sns.boxplot(x="default", y=comb[0], data=df, ax=ax[0, 0])
                sns.boxplot(x="default", y=comb[1], data=df, ax=ax[0, 1])
            else:
                df[comb[0]].hist(ax=ax[0, 0], bins=100)
                df[comb[1]].hist(ax=ax[0, 1], bins=100)
        else:
            if diagtype == "boxplot":
                ax[0, 0].set_xlabel('default',fontsize='xx-large')
                sns.boxplot(x="default", y=comb[0], data=df, ax=ax[0, 0])
            else:
                df[comb[0]].hist(ax=ax[0, 0], bins=100)
        plt.tight_layout()


numplothist(df_train)

# %%
numplothist(vis_data.query('sample == 1'),"boxplot")

# %%
decl0 = vis_data.query('sample == 1')[vis_data.query('sample == 1').default==0]['decline_app_cnt'].value_counts(bins=6)
display(decl0)
decl1 = vis_data.query('sample == 1')[vis_data.query('sample == 1').default==1]['decline_app_cnt'].value_counts(bins=6)
display(decl1)
#возможно, неверно считать выбросами порядка 25 отказанных кредитов,такое наверное может быть,
#так же как и остальные зоны выбросов в соответствии с boxplot по income и bki_request_cnt
# Out:
# (-0.034, 5.5]    64268
# (5.5, 11.0]        149
# (11.0, 16.5]         8
# (27.5, 33.0]         1
# (22.0, 27.5]         1
# (16.5, 22.0]         0
# Name: decline_app_cnt, dtype: int64
# (-0.023, 3.667]     9130
# (3.667, 7.333]       211
# (7.333, 11.0]         27
# (18.333, 22.0]         2
# (14.667, 18.333]       1
# (11.0, 14.667]         1
# Name: decline_app_cnt, dtype: int64

# %%
sns.ecdfplot(data=vis_data.query('sample == 1'), x="decline_app_cnt",hue='default',stat="count")
# Out:
# <AxesSubplot:xlabel='decline_app_cnt', ylabel='Count'>

# %%
sns.ecdfplot(data=vis_data.query('sample == 1')[vis_data.query('sample == 1').income<50000], x="income",hue='default',stat="count")
# Out:
# <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
sns.ecdfplot(data=vis_data.query('sample == 1'), x="income",hue='default',stat="count")
#среди клиентов с разным доходом - доля не отдающих кредиты сохраняется почти неизменной
# Out:
# <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
#создать рабочую копию выборки
df=vis_data.copy()
#распределение признаков 'decline_app_cnt','bki_request_cnt', 'income' - 
#будет иметь более удобный для анализа вид, если их прологарифмировать
for i in ['decline_app_cnt','bki_request_cnt', 'income']:
    df[i] = df[i].apply(lambda w: np.log(w + 1))

# %%
numplothist(df)

# %%
numplothist(df.query('sample == 1'),"boxplot")

# %%
#оценка корелляции числовых признаков:
sns.heatmap(df[num_cols].corr().abs(), vmin=0, vmax=1)
#связь признаков между собой низкая
# Out:
# <AxesSubplot:>

# %%
#оценка значимости числовых признаков
imp_num = pd.Series(f_classif(df.query('sample == 1')[num_cols], df.query('sample == 1')['default'])[0], index = num_cols)
imp_num.sort_values(inplace = True)
imp_num.plot(kind = 'barh')
#наиболее значимые признаки 'score_bki','decline_app_cnt'
# Out:
# <AxesSubplot:>

# %%
#выполнить кодировку бинарных и категориальных(строковых) признаков в цифру:
#(((!!!промежуточные оценки до использования OneHotEncoder для категориальных!!!)))
#использовать LabelEncoder

label_encoder = LabelEncoder()

#(good_work уже изначально был 0/1, его можно не трогать)
for column in list(set(bin_cols).union(set(['education']))-set(['good_work '])):
    df[column] = label_encoder.fit_transform(df[column])
    
df.head()
# Out:
#    client_id  education  sex  age  car  car_type  decline_app_cnt  good_work  \
# 0      74835          1    1   29    1         1         0.000000          0
# 1      17527          3    0   39    0         0         1.791759          0
# 2      75683          4    1   50    1         1         0.000000          0
# 3      26883          3    1   56    0         0         0.000000          0
# 4      28862          1    0   38    0         0         0.000000          0
#
#    score_bki  bki_request_cnt  region_rating  home_address  work_address  \
# 0  -2.271884         1.386294             50             1             2
# 1  -1.504999         1.098612             50             1             2
# 2  -1.691339         0.693147             50             1             2
# 3  -2.374182         0.693147             40             1             2
# 4  -2.487502         0.000000             80             2             3
#
# ...

# %%
#список всех значимых признаков
allfeatchers=list(set(df.columns)-set(['default','client_id','sample']))
allfeatchers
# Out:
# ['car_type',
#  'first_time',
#  'car',
#  'good_work',
#  'score_bki',
#  'income',
#  'decline_app_cnt',
#  'foreign_passport',
#  'bki_request_cnt',
#  'home_address',
#  'sex',
#  'region_rating',
#  'education',
#  'work_address',
#  'age',
#  'sna']

# %%
#проверка значимости категориальных признаков специальной функцией mutual_info_classif:
imp_cat = Series(mutual_info_classif(df.query('sample == 1')[bin_cols + cat_cols], df.query('sample == 1')['default'],
                                     discrete_features =True), index = bin_cols + cat_cols)
imp_cat.sort_values(inplace = True)
imp_cat.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
#оценка корелляции категориальных признаков:
sns.heatmap(df[bin_cols + cat_cols].corr().abs(), vmin=0, vmax=1)
#car_type,car -car кандидат для удаления - как менее значимый?
#work_address и home_address  - , удалить work_address?
#sna и first_time: удалить first_time? или сделать комбинацию этих признаков в новый признак
# Out:
# <AxesSubplot:>

# %%
#результаты оценки значимости из всех признаков, включая числовые и категориальные
#методом f_classif не показывает явных противоречий оценке специальным методом mutual_info_classif:
#score_bki по-прежнему на первом месте
imp_num = pd.Series(f_classif(df.query('sample == 1')[allfeatchers], df.query('sample == 1')['default'])[0], index = allfeatchers)
imp_num.sort_values(inplace = True)
imp_num.plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
#признаки car_type,car и income - высоко скореллированы,
#car и income - кандидаты для удаления - как менее значимые или сделать комбинацию этих признаков ву новый признак
#work_address и home_address - тоже, удалить work_address или сделать комбинацию этих признаков ву новый признак
#sna и first_time

# %%
#оценка корелляции всех признаков:
sns.heatmap(df[allfeatchers].corr().abs(), vmin=0, vmax=1)
# Out:
# <AxesSubplot:>

# %%
#отображение начальных строковых категорий и их же,перекодированных в цифру
for i in (bin_cols+cat_cols):
    print(i, "vis_data:", vis_data[i].unique())
    print(i, "      df:", df[i].unique())
# Out:
# sex vis_data: ['M' 'F']
# sex       df: [1 0]
# car vis_data: ['Y' 'N']
# car       df: [1 0]
# car_type vis_data: ['Y' 'N']
# car_type       df: [1 0]
# good_work vis_data: [0 1]
# good_work       df: [0 1]
# foreign_passport vis_data: ['N' 'Y']
# foreign_passport       df: [0 1]
# education vis_data: ['GRD' 'SCH' 'UGR' 'PGR' 'other' 'ACD']
# education       df: [1 3 4 2 5 0]
# region_rating vis_data: [50 40 80 60 70 20 30]
# region_rating       df: [50 40 80 60 70 20 30]
# home_address vis_data: [1 2 3]
# home_address       df: [1 2 3]
# work_address vis_data: [2 3 1]
# work_address       df: [2 3 1]
# sna vis_data: [1 4 2 3]
# sna       df: [1 4 2 3]
# first_time vis_data: [4 3 1 2]
# first_time       df: [4 3 1 2]

# %%
#визуализация соотношения вариантов целевой переменной в тренировочной и тестовой выборках
def visualize_train_valid_counts(init_data, y_train, y_test):
    x = np.array([0, 1])
    width = 0.4

    plt.figure(figsize=(15, 8))
    ax = plt.subplot(111)

    classes = list(init_data['default'].value_counts().index)

    ax.bar(x - width, list(init_data['default'].value_counts()[classes]), width, color='r', label='Исходные данные')
    ax.bar(x, [np.sum(y_train==0),np.sum(y_train==1)], width, color='g', label='Тренировочная выборка')
    ax.bar(x, [np.sum(y_test==0),np.sum(y_test==1)], width, bottom=[np.sum(y_train==0),np.sum(y_train==1)], color='b', label='Валидационная выборка')

#     ax.set_ylim([0, 70])
    plt.xticks(x - width / 2, classes, fontsize=20)
    plt.yticks(fontsize=15)
    plt.xlabel('Значение целевой переменной default', fontsize=20)
    plt.ylabel('Кол-во примеров', fontsize=20)
    plt.minorticks_on()
    plt.grid(which='major', color='r')
    plt.grid(which='minor', linestyle=':', color='k')
    plt.legend(fontsize=15)

# %%
def pltroc(fpr, tpr, roc_auc):  # построение графика ROC AUC
    plt.figure()
    plt.plot([0, 1], label='Baseline', linestyle='--')
    plt.plot(fpr, tpr, label='Regression')
    plt.title('Logistic Regression ROC AUC = %0.3f' % roc_auc)
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.legend(loc='lower right')
    plt.show()

# %%
# класс для основных операций по применению к датасету логистической регрессии
class LogReg():
    def __init__(self, df, bin_cols, cat_cols, num_cols):
        self.df = df
        self.X_train, self.X_test, self.y_train, self.y_test = None, None, None, None
        self.y_pred, self.probs, self.model, self.clf = None, None, None, None
        print("Создан объект класса LogReg")

    def traintest_split(self, fixsplit=None):
        def tmp(df):  # кодирование/стандартизация
            X_cat = OneHotEncoder(
                sparse=False).fit_transform(df[cat_cols].values)
            # Стандартизация числовых переменных
            X_num = StandardScaler().fit_transform(df[num_cols].values)
            # Объединение подготовленных значений в единую группу для передачи в модель
            X = np.hstack([X_num, df[bin_cols].values, X_cat])
            return X

            # кодирование категориальных переменных
        if fixsplit is None:  # разделить с помощью библиотеки только тренировочную выборку
            self.X = tmp(self.df.query('sample == 1'))
            self.Y = self.df.query('sample == 1')['default'].values
            self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(
                self.X, self.Y, test_size=0.20, random_state=42)
        else:
            # использовать готовую полную тренировочную и учебную тестовую с отсутствующими дефолтами
            self.X_train = tmp(self.df.query('sample == 1'))
            self.X_test = tmp(self.df.query('sample == 0'))
            self.y_train = df.query('sample == 1')['default'].values
            #self.y_test - неизвестен

    def pltsplit(self):  # график количественного соотношения тренировочной и тестовой выборок
        if self.y_train is None:
            raise Exception('Call traintest_split first')
        visualize_train_valid_counts(self.df, self.y_train, self.y_test)

    def pltrocauc(self):  # график метрики рокаук
        if self.probs is None:
            raise Exception('Call predict first')
        fpr, tpr, threshold = roc_curve(self.y_test, self.probs[:, 1])
        roc_auc = roc_auc_score(self.y_test, self.probs[:, 1])
        pltroc(fpr, tpr, roc_auc)

    def fit(self):  # обучение модели
        if self.y_train is None:
            raise Exception('Call traintest_split first')
        self.model = LogisticRegression(max_iter=300)
        self.model.fit(self.X_train, self.y_train)
    
    def bestfit(self):  # обучение модели с последними параметрами регуляризации
        if self.model is None:
            raise Exception('Call fit first')
        self.model.fit(self.X_train, self.y_train)

    def searchCV(self, C):  # поиск по сетке гиперпараметров
        hyperparameters = dict(C=C)  # , penalty=penalty
        # Создаем сетку поиска с использованием 5-кратной перекрестной проверки
        self.clf = GridSearchCV(self.model, hyperparameters, cv=5, verbose=3)
        print('Start search C')
        self.best_model = self.clf.fit(self.X_train, self.y_train)
        print('End search C')
        print('Лучшее C:', self.best_model.best_estimator_.get_params()['C'])
        self.model = self.best_model.best_estimator_

    def searchHalv(self, C, max_iterint):  # альтернативный поиск по сетке гиперпараметров
        hyperparameters = dict(C=C, max_iter=max_iterint)  # , penalty=penalty
        # Создаем сетку поиска с использованием 5-кратной перекрестной проверки
        self.clf = HalvingGridSearchCV(
            self.model, hyperparameters, cv=5, verbose=3, factor=2, random_state=0)
        print('Start search C')
        self.best_model = self.clf.fit(self.X_train, self.y_train)
        print('End search C')
        print('Лучшее C:', self.best_model.best_estimator_.get_params()['C'])
        self.model = self.best_model.best_estimator_

    def predict(self):  # применение модели к выборке для получения предсказания
        if self.model is None:
            raise Exception('Call fit first')
        self.probs = self.model.predict_proba(self.X_test)
        self.y_pred = self.model.predict(self.X_test)

    def printmetrics(self):  # вывод различных метрик
        if self.y_pred is None:
            raise Exception('Call predict first')
        # вычисление log_loss
        y_hat = np.zeros((len(self.y_test), 2), dtype=np.float32)
        for num in range(2):
            y_hat[:, num] = 1. * (self.y_pred == num)
        print('log_loss: {:.4f}'.format(log_loss(self.y_test, y_hat)))
        acc = accuracy_score(self.y_test, self.y_pred)
        print('Accuracy from scikit-learn: {}%'.format(acc * 100))
        precision = precision_score(self.y_test, 1 - self.y_pred)
        recall = recall_score(self.y_test, 1 - self.y_pred)
        print('precision: {:.2f}\nrecall: {:.2f}'.format(precision, recall))
        f1 = f1_score(self.y_test, self.y_pred)
        print('F1-score: {:.2f}'.format(f1))
        ap = average_precision_score(self.y_test, self.y_pred)
        print('Average Precision (AP) = {:.2f}'.format(ap))

    def pltprecrec(self):  # вывод различных метрик
        precisions, recalls, _ = precision_recall_curve(
            self.y_test, self.y_pred)
        plt.step(recalls, precisions, color='b', alpha=0.2, where='post')
        plt.fill_between(recalls, precisions, step='post',
                         alpha=0.2, color='b')
        plt.xlabel('Recall')
        plt.ylabel('Precision')

    def printconfmatrx(self):  # вывод confusion_matrix
        conf_mat = confusion_matrix(self.y_test, self.y_pred).T
        print('Confusion matrix:\n{}'.format(conf_mat))

# %%
splitcolumnsbyt(df,verb=True)
# Out:
# разбивка столбцов на бинарные, категориальные и числовые признаки
# 'бинарные:'
# ['sex', 'car', 'car_type', 'good_work', 'foreign_passport']
# 'категориальные:'
# ['education',
#  'region_rating',
#  'home_address',
#  'work_address',
#  'sna',
#  'first_time']
# 'числовые:'
# ['age', 'decline_app_cnt', 'score_bki', 'bki_request_cnt', 'income']
# отображение многообразия вариаций нечисловых столбцов
# sex : [1 0]
# car : [1 0]
# car_type : [1 0]
# good_work : [0 1]
# foreign_passport : [0 1]
# education : [1 3 4 2 5 0]
# region_rating : [50 40 80 60 70 20 30]
# home_address : [1 2 3]
# work_address : [2 3 1]
# sna : [1 4 2 3]
# first_time : [4 3 1 2]

# %%
logreg = LogReg(df,bin_cols,cat_cols,num_cols)
# Out:
# Создан объект класса LogReg

# %%
#разделение части train с известным дефолтом на тренировочную и тестовую части
logreg.traintest_split()
logreg.pltsplit()

# %%
logreg.fit()
logreg.predict()

# %%
logreg.pltrocauc()

# %%
logreg.printmetrics()
# Out:
# log_loss: 4.3056
# Accuracy from scikit-learn: 87.53387533875339%
# precision: 0.12
# recall: 0.98
# F1-score: 0.04
# Average Precision (AP) = 0.13

# %%
logreg.pltprecrec()

# %%
logreg.printconfmatrx()
# Out:
# Confusion matrix:
# [[12881  1788]
#  [   52    39]]

# %%
#проверка правильности предположения
qq=vis_data[(vis_data.car=='N') & (vis_data.car_type=='Y')]
print(len(qq))
#если машины нет, то это и не иномарка, а если машина есть, то она может быть, а может и не быть иномаркой.
#в таком случае комбинация двух скореллированных признаков в один путем суммы (после кодирования в 0/1)
#в отличие от категориального признака является "числовым", т.к. 0 - нет машины, 1 - есть отечественная машина, 2 - есть иномарка-
# в данном случае можно сказать , что 2 лучше, чем 1 и 1 лучше , чем 0
#сделать новый числовой признак:
df["aboutcar"]=df.apply(lambda x:x.car+x.car_type, axis=1)
#сделать новый категориальный признак на основе скореллированных двух:
df["homework_addr"]=df.apply(lambda x:x.home_address+x.work_address, axis=1)
#удалить начальные признаки
df.drop(columns=['car', 'car_type','home_address','work_address'], inplace=True)
# Out:
# 0

# %%
def postperform(): #спец функция для адаптации стандартной разбивки столбцов по типам(бинарный, категориальный, числовой,
    #т.к. заведомо принято, что aboutcar будет числовой)
    cat_cols.remove('aboutcar')
    num_cols.append('aboutcar')

splitcolumnsbyt(df,postperform=postperform,verb=True)
# Out:
# разбивка столбцов на бинарные, категориальные и числовые признаки
# 'бинарные:'
# ['sex', 'good_work', 'foreign_passport']
# 'категориальные:'
# ['education', 'region_rating', 'sna', 'first_time', 'homework_addr']
# 'числовые:'
# ['age',
#  'decline_app_cnt',
#  'score_bki',
#  'bki_request_cnt',
#  'income',
#  'aboutcar']
# отображение многообразия вариаций нечисловых столбцов
# sex : [1 0]
# good_work : [0 1]
# foreign_passport : [0 1]
# education : [1 3 4 2 5 0]
# region_rating : [50 40 80 60 70 20 30]
# sna : [1 4 2 3]
# first_time : [4 3 1 2]
# homework_addr : [3. 5. 6. 4. 2.]

# %%
logreg.traintest_split()
logreg.fit()
logreg.predict()
logreg.pltrocauc()
logreg.printmetrics()
logreg.pltprecrec()
logreg.printconfmatrx()
# Out:
# log_loss: 4.3010
# Accuracy from scikit-learn: 87.54742547425475%
# precision: 0.12
# recall: 0.98
# F1-score: 0.04
# Average Precision (AP) = 0.13
# Confusion matrix:
# [[12879  1784]
#  [   54    43]]

# %%
#за счет новых признаков едва заметно качество улучшилось, что видно по матрице Confusion -
#увеличилось TP, уменьшилось FN (чуть хуже стало FP)

# %%
#добавление нового признака, найденного перебором комбинаций (ниже),
#который дает улучшение  согласно новой матрице Confusion 
splitcolumnsbyt(df,postperform=postperform)
newfeatcher='score_bkiincome'
df[newfeatcher]=df.apply(lambda x:x['score_bki'] * x['income']+ x['decline_app_cnt']+x['aboutcar'], axis=1)
num_cols.append(newfeatcher)
print(newfeatcher,num_cols)

logreg.traintest_split()
logreg.fit()
logreg.predict()
logreg.pltrocauc()
logreg.printmetrics()
logreg.printconfmatrx()
# df.drop(columns=[newfeatcher], inplace=True)
# num_cols.remove(newfeatcher)
# print("***",newfeatcher)
# Out:
# score_bkiincome ['age', 'decline_app_cnt', 'score_bki', 'bki_request_cnt', 'income', 'aboutcar', 'score_bkiincome']
# log_loss: 4.2963
# Accuracy from scikit-learn: 87.5609756097561%
# precision: 0.12
# recall: 0.97
# F1-score: 0.05
# Average Precision (AP) = 0.13
# Confusion matrix:
# [[12877  1780]
#  [   56    47]]

# %%
#альтернативный поиск
#logreg.search(np.logspace(1, 5, num=200))

# %%
logreg.searchHalv(np.logspace(1, 5, num=100),[500]) #max число итераций 500
# Out:
# Start search C
# n_iterations: 7
# n_required_iterations: 7
# n_possible_iterations: 7
# min_resources_: 922
# max_resources_: 59039
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 100
# n_resources: 922
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END C=10.0, max_iter=500;, score=(train=0.890, test=0.864) total time=   0.0s
# [CV 2/5] END C=10.0, max_iter=500;, score=(train=0.894, test=0.864) total time=   0.0s
# [CV 3/5] END C=10.0, max_iter=500;, score=(train=0.883, test=0.875) total time=   0.0s
# [CV 4/5] END C=10.0, max_iter=500;, score=(train=0.881, test=0.842) total time=   0.0s
# [CV 5/5] END C=10.0, max_iter=500;, score=(train=0.863, test=0.853) total time=   0.0s
# [CV 1/5] END C=10.974987654930562, max_iter=500;, score=(train=0.890, test=0.864) total time=   0.0s
# [CV 2/5] END C=10.974987654930562, max_iter=500;, score=(train=0.894, test=0.864) total time=   0.0s
# ...

# %%
logreg.model.get_params()
# Out:
# {'C': 135.30477745798075,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
logreg.bestfit()
logreg.pltrocauc()
logreg.printmetrics()
logreg.pltprecrec()
logreg.printconfmatrx()
# Out:
# log_loss: 4.2963
# Accuracy from scikit-learn: 87.5609756097561%
# precision: 0.12
# recall: 0.97
# F1-score: 0.05
# Average Precision (AP) = 0.13
# Confusion matrix:
# [[12877  1780]
#  [   56    47]]

# %%
#получение предсказаний для тестовой выборки с отсутствующими дефолтами
logreg.traintest_split(fixsplit=True) #использовать полную тренировочную
logreg.bestfit()
logreg.predict()

# %%
list(sample_submission.columns)
# Out:
# ['client_id', 'default']

# %%
len(logreg.probs[:, 1])
# Out:
# 36349

# %%
sample_submission=df.query('sample == 0').drop(['sample'],axis=1)
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36349 entries, 0 to 36348
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         36349 non-null  int64
#  1   education         36349 non-null  int32
#  2   sex               36349 non-null  int32
#  3   age               36349 non-null  int64
#  4   decline_app_cnt   36349 non-null  float64
#  5   good_work         36349 non-null  int64
#  6   score_bki         36349 non-null  float64
#  7   bki_request_cnt   36349 non-null  float64
#  8   region_rating     36349 non-null  int64
#  9   income            36349 non-null  float64
#  10  sna               36349 non-null  int64
#  11  first_time        36349 non-null  int64
#  12  foreign_passport  36349 non-null  int32
#  13  default           36349 non-null  int64
#  14  aboutcar          36349 non-null  float64
#  15  homework_addr     36349 non-null  float64
# ...

# %%
sample_submission['default']=logreg.probs[:, 1] #вероятность исхода 1, т.е. невозврата кредита
todel=list(sample_submission.columns)
todel.remove('client_id')
todel.remove('default')
sample_submission.drop(todel,axis=1,inplace=True) #удалить все кроме нужных двух столбцов
sample_submission.query('client_id==69942')
# Out:
#        client_id   default
# 31926      69942  0.104769

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36349 entries, 0 to 36348
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  36349 non-null  int64
#  1   default    36349 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 851.9 KB

# %%
sample_submission.sample(5)
# Out:
#        client_id   default
# 8370       87176  0.345253
# 21917      56569  0.100563
# 33248       3153  0.024744
# 6343       70667  0.077557
# 25947      78852  0.126862

# %%
sample_submission['default'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
sample_submission.to_csv('submission.csv', index=False)

# %%
logreg.model.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
#ниже идет код перебора комбинаций новых признаков

# %%
# import itertools as it
# #сформировать попарные комбинации
# splitcolumnsbyt(df,postperform=postperform)
# zz=list(it.combinations(num_cols,3))
# print(num_cols)
# for comb in zz:
#     newfeatcher=comb[0] + comb[1]+ comb[2]
#     df[newfeatcher]=df.apply(lambda x:x[comb[0]] * x[comb[1]]+ x[comb[2]], axis=1)
#     num_cols.append(newfeatcher)
#     print(newfeatcher,num_cols)
#     logreg = LogReg(df,bin_cols,cat_cols,num_cols)
#     logreg.traintest_split()
#     logreg.fit()
#     logreg.predict()
#     logreg.pltrocauc()
#     logreg.printmetrics()
#     logreg.printconfmatrx()
#     df.drop(columns=[newfeatcher], inplace=True)
#     num_cols.remove(newfeatcher)
#     print("***",newfeatcher)

# %%
# zz=list(it.combinations(num_cols,3))
# zz
